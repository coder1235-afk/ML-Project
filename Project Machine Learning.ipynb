# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("pcos_prediction_dataset.csv")
df
# Out:
#            Country  Age          BMI Menstrual Regularity Hirsutism  \
# 0       Madagascar   26   Overweight              Regular       Yes
# 1          Vietnam   16  Underweight              Regular       Yes
# 2          Somalia   41       Normal              Regular        No
# 3           Malawi   27       Normal            Irregular        No
# 4           France   26   Overweight            Irregular       Yes
# ...            ...  ...          ...                  ...       ...
# 119995      Guinea   28       Normal              Regular        No
# 119996  Mozambique   35   Overweight              Regular        No
# 119997    Cambodia   16       Normal              Regular        No
# 119998       Benin   15        Obese              Regular       Yes
# 119999      Brazil   17        Obese            Irregular       Yes
#
#        Acne Severity Family History of PCOS Insulin Resistance  \
# 0             Severe                    Yes                Yes
# ...

# %% [markdown]
# <!-- Data Types -->

# %% [markdown]
# <!-- Data Types -->

# %% [markdown]
# # Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Country                      120000 non-null  object
#  1   Age                          120000 non-null  int64
#  2   BMI                          120000 non-null  object
#  3   Menstrual Regularity         120000 non-null  object
#  4   Hirsutism                    120000 non-null  object
#  5   Acne Severity                59915 non-null   object
#  6   Family History of PCOS       120000 non-null  object
#  7   Insulin Resistance           120000 non-null  object
#  8   Lifestyle Score              120000 non-null  int64
#  9   Stress Levels                120000 non-null  object
#  10  Urban/Rural                  120000 non-null  object
#  11  Socioeconomic Status         120000 non-null  object
# ...

# %% [markdown]
# # Drop a Column

# %%
df=df.drop(columns="Acne Severity")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Country                      120000 non-null  object
#  1   Age                          120000 non-null  int64
#  2   BMI                          120000 non-null  object
#  3   Menstrual Regularity         120000 non-null  object
#  4   Hirsutism                    120000 non-null  object
#  5   Family History of PCOS       120000 non-null  object
#  6   Insulin Resistance           120000 non-null  object
#  7   Lifestyle Score              120000 non-null  int64
#  8   Stress Levels                120000 non-null  object
#  9   Urban/Rural                  120000 non-null  object
#  10  Socioeconomic Status         120000 non-null  object
#  11  Awareness of PCOS            120000 non-null  object
# ...

# %% [markdown]
# # Using Label Encoder To Change The Data

# %%
le = LabelEncoder()
df["Country"] = le.fit_transform(df["Country"])
df["BMI"] = le.fit_transform(df["BMI"])
df["Menstrual Regularity"] = le.fit_transform(df["Menstrual Regularity"])
df["Hirsutism"] = le.fit_transform(df["Hirsutism"])
df["Family History of PCOS"] = le.fit_transform(df["Family History of PCOS"])
df["Insulin Resistance"] = le.fit_transform(df["Insulin Resistance"])
df["Menstrual Regularity"] = le.fit_transform(df["Menstrual Regularity"])
df["Stress Levels"] = le.fit_transform(df["Stress Levels"])
df["Urban/Rural"] = le.fit_transform(df["Urban/Rural"])
df["Socioeconomic Status"] = le.fit_transform(df["Socioeconomic Status"])
df["Awareness of PCOS"] = le.fit_transform(df["Awareness of PCOS"])
df["Fertility Concerns"] = le.fit_transform(df["Fertility Concerns"])
df["Ethnicity"] = le.fit_transform(df["Ethnicity"])
df["Diagnosis"] = le.fit_transform(df["Diagnosis"])

# %% [markdown]
# <!-- Drop Column -->

# %%
df
# Out:
#         Country  Age  BMI  Menstrual Regularity  Hirsutism  \
# 0            34   26    2                     1          1
# 1            73   16    3                     1          1
# 2            56   41    0                     1          0
# 3            35   27    0                     0          0
# 4            20   26    2                     0          1
# ...         ...  ...  ...                   ...        ...
# 119995       24   28    0                     1          0
# 119996       40   35    2                     1          0
# 119997       10   16    0                     1          0
# 119998        6   15    1                     1          1
# 119999        7   17    1                     0          1
#
#         Family History of PCOS  Insulin Resistance  Lifestyle Score  \
# 0                            1                   1                2
# 1                            0                   1                4
# ...

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %%
x = df.drop(columns = "Menstrual Regularity")
x
z = df.iloc[:,3]

# %%
x_train,x_test,z_train,z_test= train_test_split(x,z,test_size=0.2,random_state=55)

# %% [markdown]
# # Importing Algorithm

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train,z_train)
# Out:
# RandomForestClassifier()

# %%
pred = rfc.predict(x_test)

# %%
x_train,x_test,z_train,z_test= train_test_split(x,z,test_size=0.2,random_state=95)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,z_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dtc.predict(x_test)

# %%
accuracy = accuracy_score(z_test, pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 accuracy = accuracy_score(z_test, pred)
#
# NameError: name 'accuracy_score' is not defined

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train,z_train)

# %%
pre = lg.predict(x_test)

# %% [markdown]
# # Cheking The Accuracy Of The Model

# %%
from sklearn.metrics import classification_report
print(classification_report(z_test,pred))

# %%
print(f"Accuracy of the Decision Tree: {accuracy * 100:.2f}%")

# %%
from sklearn.metrics import classification_report
print(classification_report(z_test,pred))

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x="Age", y="Lifestyle Score", hue="Menstrual Regularity", data=df)
plt.title("Age vs. Lifestyle Score Colored by Menstrual Regularity")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x="Menstrual Regularity", y="BMI", data=df)
plt.title("BMI Distribution by Menstrual Regularity")
plt.show()
